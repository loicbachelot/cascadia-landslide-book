# %% [markdown]
# # This is a temporary notebook used for doing some initial analysis. This is not updated for the new pipeline.

# %% [markdown]
# # Load the Combined Dataset

# %%
import fiona
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
landslides = gpd.read_file('./bc_or_wa_merged_landslides.geojson')

# %%
print(landslides.shape)

landslides.head()
# Out:
# (90618, 53)
#   Reference Type_details Contributo DATE_RANGE  Latitude  Longitude  \
# 0      None         None       None       None       NaN        NaN
# 1      None         None       None       None       NaN        NaN
# 2      None         None       None       None       NaN        NaN
# 3      None         None       None       None       NaN        NaN
# 4      None         None       None       None       NaN        NaN
#
#        SLOPE MOVEMENT  Type Resource_road_type  ... Point_location  Comment  \
# 0   4.256579     Flow  None               None  ...           None     None
# 1   3.350513     Flow  None               None  ...           None     None
# 2   5.811321     Flow  None               None  ...           None     None
# 3   5.413578     Flow  None               None  ...           None     None
# 4  13.638928     Flow  None               None  ...           None     None
#
#      Shape_Area MVMT_AZIMUTH_DEG Volume_estimate_method Shape_Length  \
# 0  11291.764767              0.0                   None   447.239405
# 1  13701.014637            180.0                   None   455.775817
# 2  14879.315815            337.5                   None   568.959463
# 3  20034.804942            315.0                   None   591.097110
# 4   8462.716893            270.0                   None   391.627031
#
#   REACTIVATION                     GEOL AVG_SCARP_DIST_FT  \
# 0         None    vol.M.cr.gr.nd.nd.bas               0.0
# 1         None    vol.M.cr.gr.nd.nd.bas               0.0
# 2         None    vol.M.cr.gr.nd.nd.bas               0.0
# 3         None  sed.Q.qsd.mf.nd.nd.fine               0.0
# 4         None    vol.M.cr.gr.nd.nd.bas               0.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.88334 45.36111, -122.8832...
# 1  MULTIPOLYGON (((-122.88317 45.36171, -122.8831...
# 2  MULTIPOLYGON (((-122.88144 45.36087, -122.8814...
# 3  MULTIPOLYGON (((-122.87991 45.36164, -122.8800...
# 4  MULTIPOLYGON (((-122.88515 45.35148, -122.885 ...
#
# [5 rows x 53 columns]

# %%
landslides.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 90618 entries, 0 to 90617
# Data columns (total 53 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Reference                  4240 non-null   object
#  1   Type_details               4240 non-null   object
#  2   Contributo                 4240 non-null   object
#  3   DATE_RANGE                 386 non-null    object
#  4   Latitude                   4240 non-null   float64
#  5   Longitude                  4240 non-null   float64
#  6   SLOPE                      75139 non-null  float64
#  7   MOVEMENT                   90618 non-null  object
#  8   Type                       4240 non-null   object
#  9   Resource_road_type         4240 non-null   object
#  10  TYPE_MOVE                  42383 non-null  object
#  11  HS_HEIGHT                  65508 non-null  float64
#  12  VOLUME                     15055 non-null  float64
#  13  NAME                       8378 non-null   object
#  14  Study_area                 4240 non-null   object
#  15  MONTH                      81 non-null     object
#  16  Discharge estimate (m3/s)  4240 non-null   object
#  17  CONFIDENCE                 60480 non-null  object
#  18  YEAR                       723 non-null    object
#  19  MAP_UNIT_L                 34199 non-null  object
#  20  FAIL_DEPTH                 65544 non-null  float64
#  21  Event_verification         4240 non-null   object
#  22  Bedrock_type               4240 non-null   object
#  23  DATE_MOVE                  3932 non-null   object
#  24  RELATIVE_AGE               57448 non-null  object
#  25  MOVE_CODE                  57331 non-null  object
#  26  Trigger                    4240 non-null   object
#  27  Resource_road_activity     4240 non-null   object
#  28  Cont_details               4240 non-null   object
#  29  DEEP_SHAL                  29868 non-null  object
#  30  DESCRIPTION                71318 non-null  object
#  31  MATERIAL                   90618 non-null  object
#  32  Watercours                 4240 non-null   object
#  33  Timing                     4240 non-null   object
#  34  AREA                       65511 non-null  object
#  35  VOL                        58717 non-null  float64
#  36  original_dataset           90618 non-null  object
#  37  Material                   4240 non-null   object
#  38  Size_class                 4240 non-null   object
#  39  LANDSLIDE_ID               90618 non-null  object
#  40  REF_ID_COD                 71318 non-null  object
#  41  FAN_HEIGHT                 44436 non-null  float64
#  42  DAY                        42 non-null     object
#  43  Point_location             4240 non-null   object
#  44  Comment                    4240 non-null   object
#  45  Shape_Area                 86378 non-null  float64
#  46  MVMT_AZIMUTH_DEG           73122 non-null  float64
#  47  Volume_estimate_method     4240 non-null   object
#  48  Shape_Length               86378 non-null  float64
#  49  REACTIVATION               21 non-null     object
#  50  GEOL                       41432 non-null  object
#  51  AVG_SCARP_DIST_FT          48069 non-null  float64
#  52  geometry                   90618 non-null  geometry
# dtypes: float64(12), geometry(1), object(40)
# memory usage: 36.6+ MB

# %%
origin_count = landslides['original_dataset'].value_counts()
print(origin_count)
# Out:
# original_dataset
# OR    71318
# WA    15060
# BC     4240
# Name: count, dtype: int64

# %%
# Calculate completeness for each column
def calculate_completeness(df):
    completeness = {}
    total_rows = len(df)
    
    for col in df.columns:
        # Count non-null values that are not empty strings
        filled_count = df[col].notna().sum() - (df[col] == '').sum()
        completeness_pct = (filled_count / total_rows) * 100
        completeness[col] = completeness_pct
    
    return pd.Series(completeness).sort_values(ascending=False)

completeness_results = calculate_completeness(landslides)
print("Column Completeness (% filled):")
print(completeness_results.round(2))
# Out:
# Column Completeness (% filled):
# geometry                     100.00
# original_dataset             100.00
# MATERIAL                     100.00
# MOVEMENT                     100.00
# LANDSLIDE_ID                 100.00
# Shape_Area                    95.32
# Shape_Length                  95.32
# SLOPE                         82.92
# VOLUME_MERGED                 81.41
# MVMT_AZIMUTH_DEG              80.69
# DESCRIPTION                   78.70
# REF_ID_COD                    78.70
# FAIL_DEPTH                    72.33
# HS_HEIGHT                     72.29
# AREA                          72.20
# CONFIDENCE                    66.74
# RELATIVE_AGE                  63.40
# MOVE_CODE                     63.27
# AVG_SCARP_DIST_FT             53.05
# FAN_HEIGHT                    49.04
# TYPE_MOVE                     46.77
# GEOL                          45.72
# MAP_UNIT_L                    37.74
# DEEP_SHAL                     32.95
# NAME                           9.24
# Longitude                      4.68
# Latitude                       4.68
# Type                           4.68
# Material                       4.68
# Discharge estimate (m3/s)      4.58
# DATE_MOVE                      4.34
# Point_location                 3.31
# Timing                         2.47
# Reference                      2.05
# Trigger                        2.05
# Event_verification             1.67
# Contributo                     1.61
# Watercours                     1.06
# Study_area                     0.97
# Cont_details                   0.90
# YEAR                           0.78
# Type_details                   0.46
# DATE_RANGE                     0.43
# Size_class                     0.28
# Resource_road_type             0.22
# Resource_road_activity         0.22
# Bedrock_type                   0.12
# Comment                        0.11
# Volume_estimate_method         0.10
# MONTH                          0.09
# DAY                            0.05
# REACTIVATION                   0.02
# dtype: float64
# /var/folders/4l/861pz_dj397_gz1sywdvrptw0000gq/T/ipykernel_89009/1950950771.py:8: UserWarning: GeoSeries.notna() previously returned False for both missing (None) and empty geometries. Now, it only returns False for missing values. Since the calling GeoSeries contains empty geometries, the result has changed compared to previous versions of GeoPandas.
# Given a GeoSeries 's', you can use '~s.is_empty & s.notna()' to get back the old behaviour.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', 'GeoSeries.notna', UserWarning)
#   filled_count = df[col].notna().sum() - (df[col] == '').sum()

# %%
# Check for rows that have values in both VOL and VOLUME columns
both_vol_mask = landslides['VOL'].notna() & landslides['VOLUME'].notna()
rows_with_both = landslides[both_vol_mask]

if len(rows_with_both) > 0:
    print(f"Error: Found {len(rows_with_both)} rows with values in both VOL and VOLUME columns")
    print("Sample rows with both values:")
    print(rows_with_both[['VOL', 'VOLUME', 'original_dataset']].head())
else:
    print("No conflicts found. Proceeding with merge...")
    
    # Create a new merged volume column
    landslides['VOLUME_MERGED'] = landslides['VOL'].fillna(landslides['VOLUME'])
    
    # Drop the original columns
    landslides = landslides.drop(columns=['VOL', 'VOLUME'])
    
    print("Successfully merged VOL and VOLUME into VOLUME_MERGED column")
    print(f"New column has {landslides['VOLUME_MERGED'].notna().sum()} non-null values")
# Out:
# No conflicts found. Proceeding with merge...
# Successfully merged VOL and VOLUME into VOLUME_MERGED column
# New column has 73772 non-null values

# %% [markdown]
# # Column Inspection

# %% [markdown]
# ## MATERIAL

# %%
# Find the original_dataset values for each valid Material
material_by_origin = landslides[landslides['MATERIAL'].notna() & (landslides['MATERIAL'] != '')].groupby('MATERIAL')['original_dataset'].value_counts()
print("Material distribution by original dataset:")
print(material_by_origin)
# Out:
# Material distribution by original dataset:
# MATERIAL         original_dataset
# <NA>             OR                  28961
# Complex          OR                   6007
#                  BC                      7
# Debris           OR                  14719
#                  BC                   2419
# Debris+Earth     OR                      2
# Debris+Rock      OR                     17
# Earth            OR                   9105
#                  BC                    766
# Earth or debris  WA                  14712
# Earth+Rock       OR                   1110
# Other            OR                      1
# Rock             OR                  11396
#                  BC                    982
#                  WA                    348
# Submarine        BC                      3
# Water            BC                     63
# Name: count, dtype: int64

# %%
material_counts = landslides['MATERIAL'].value_counts()
print("Material counts:")
print(material_counts)
# Out:
# Material counts:
# MATERIAL
# <NA>               28961
# Debris             17138
# Earth or debris    14712
# Rock               12726
# Earth               9871
# Complex             6014
# Earth+Rock          1110
# Water                 63
# Debris+Rock           17
# Submarine              3
# Debris+Earth           2
# Other                  1
# Name: count, dtype: int64

# %% [markdown]
# ## Material                       4.68

# %%
# Find the original_dataset values for each valid Material
material_by_origin = landslides[landslides['Material'].notna() & (landslides['Material'] != '')].groupby('Material')['original_dataset'].value_counts()
print("Material distribution by original dataset:")
print(material_by_origin)
# Out:
# Material distribution by original dataset:
# Material       original_dataset
#  Surficial     BC                     2
# Anthropogenic  BC                     9
# Rock           BC                  1192
# Surficial      BC                  3033
# Surficial      BC                     4
# Name: count, dtype: int64

# %% [markdown]
# ## Movement

# %%
movement_counts = landslides['MOVEMENT'].value_counts()
print("Movement counts:")
print(movement_counts)
# Out:
# Movement counts:
# MOVEMENT
# <NA>                                28961
# Flow                                25680
# Complex                             14123
# Slide-Rotational                     9720
# Slide-Translational                  6612
# Complex+Slide-Rotational+Flow        1404
# Slide                                1119
# Fall                                 1075
# Avalanche                             624
# Flood                                 391
# Slide-Rotational+Flow                 288
# Complex+Slide-Translational+Flow      224
# Deformation                           211
# Slide-Translational+Flow               77
# Topple                                 41
# Complex+Slide+Flow                     19
# Spread                                 18
# Slide-Translational+Fall               16
# Slide+Flow+Flow+Slide                   7
# Slide+Submarine                         3
# Complex+Flow                            1
# Slide-Rotational+Fall                   1
# Slide-Translational+Flow+Fall           1
# Slide-Rotational+Spread                 1
# Slide+Fall                              1
# Name: count, dtype: int64

# %% [markdown]
# ## Slope

# %%
slope_by_origin = landslides[landslides['SLOPE'].notna()].groupby('SLOPE')['original_dataset'].value_counts()
print("Slope distribution by original dataset:")
print(slope_by_origin)
# Out:
# Slope distribution by original dataset:
# SLOPE       original_dataset
# 0.000000    OR                  17983
# 0.910504    OR                      1
# 0.929008    OR                      1
# 1.000000    OR                     33
# 1.149971    OR                      1
#                                 ...
# 75.000000   OR                      1
# 78.000000   OR                      1
# 80.000000   OR                      6
# 85.000000   OR                      1
# 315.000000  OR                      1
# Name: count, Length: 6723, dtype: int64

# %%
slope_origins = landslides[landslides['SLOPE'].notna()]['original_dataset'].unique()
print("Unique original datasets for SLOPE:")
print(slope_origins)
# Out:
# Unique original datasets for SLOPE:
# ['OR' 'WA']

# %% [markdown]
# ## MVMT_AZIMUTH_DEG

# %%
mvmt_azimuth_deg_origin = landslides[landslides['MVMT_AZIMUTH_DEG'].notna()].groupby('MVMT_AZIMUTH_DEG')['original_dataset'].value_counts()
print("Movement azimuth degrees by original dataset:")
print(mvmt_azimuth_deg_origin)
# Out:
# Movement azimuth degrees by original dataset:
# MVMT_AZIMUTH_DEG  original_dataset
# 0.0               OR                  19565
#                   WA                     43
# 20.0              OR                      1
# 22.5              OR                   2852
#                   WA                    813
#                                       ...
# 338.5             OR                      1
# 355.0             OR                      1
# 357.5             OR                      1
# 360.0             OR                   2037
#                   WA                    923
# Name: count, Length: 62, dtype: int64

# %%
mvmt_azimuth_deg_origin_origins = landslides[landslides['MVMT_AZIMUTH_DEG'].notna()]['original_dataset'].unique()
print("Unique original datasets for MVMT_AZIMUTH_DEG:")
print(mvmt_azimuth_deg_origin_origins)
# Out:
# Unique original datasets for MVMT_AZIMUTH_DEG:
# ['OR' 'WA']

# %% [markdown]
# ## FAIL_DEPTH

# %% [markdown]
# ## HS_HEIGHT

# %% [markdown]
# ## AREA

# %% [markdown]
# ## Confidence

# %% [markdown]
# ## VOL

# %%
vol_origins = landslides[landslides['VOL'].notna()]['original_dataset'].unique()
print("Unique original datasets for VOLUME:")
print(vol_origins)
# Out:
# Unique original datasets for VOLUME:
# ['OR']

# %% [markdown]
# ## RELATIVE_AGE

# %% [markdown]
# ## MOVE_CODE

# %% [markdown]
# # AVG_SCARP_DIST_FT             53.05

# %% [markdown]
# # FAN_HEIGHT                    49.04

# %% [markdown]
# # TYPE_MOVE                     46.77

# %% [markdown]
# # GEOL                          45.72

# %% [markdown]
# # MAP_UNIT_L                    37.74

# %% [markdown]
# # DEEP_SHAL                     32.95

# %% [markdown]
# # VOLUME                        16.61

# %%
volume_origins = landslides[landslides['VOLUME'].notna()]['original_dataset'].unique()
print("Unique original datasets for VOLUME:")
print(volume_origins)
# Out:
# Unique original datasets for VOLUME:
# ['WA']

# %% [markdown]
# # NAME                           9.24

# %% [markdown]
# # Longitude                      4.68
# # Latitude                       4.68

# %% [markdown]
# Type                           4.68
# Discharge estimate (m3/s)      4.58
# DATE_MOVE                      4.34
# Point_location                 3.31
# Timing                         2.47
# Reference                      2.05
# Trigger                        2.05
# Event_verification             1.67
# Contributo                     1.61
# Watercours                     1.06
# Study_area                     0.97
# Cont_details                   0.90
# YEAR                           0.78
# Type_details                   0.46
# DATE_RANGE                     0.43
# Size_class                     0.28
# Resource_road_type             0.22
# Resource_road_activity         0.22
# Bedrock_type                   0.12
# Comment                        0.11
# Volume_estimate_method         0.10
# MONTH                          0.09
# DAY                            0.05
# REACTIVATION                   0.02

# %%
# Function to find unique origins for each valid value in specified columns
def find_origins_by_value(df, columns):
    results = {}
    
    for col in columns:
        print(f"\n=== {col} ===")
        
        # Check if column exists
        if col not in df.columns:
            print(f"Column {col} not found in dataframe")
            continue
            
        # Filter for valid (non-null, non-empty) values
        valid_mask = df[col].notna() & (df[col] != '')
        
        if valid_mask.sum() == 0:
            print(f"No valid values found in {col}")
            continue
            
        # Show unique origins for this column
        unique_origins = df[valid_mask]['original_dataset'].unique()
        print(f"Unique origins: {list(unique_origins)}")
        
        # Group by column value and show origin datasets
        value_origins = df[valid_mask].groupby(col)['original_dataset'].unique()
        
        print(f"Total unique values: {len(value_origins)}")
        
        # Show first 10 values as examples
        for i, (value, origins) in enumerate(value_origins.items()):
            if i < 10:  # Show first 10 examples
                print(f"  {value}: {list(origins)}")
            elif i == 10:
                print(f"  ... and {len(value_origins) - 10} more values")
                break
        
        results[col] = value_origins
    
    return results

# All columns from your completeness results
all_columns = [
    'geometry', 'original_dataset', 'MATERIAL', 'MOVEMENT', 'LANDSLIDE_ID',
    'Shape_Area', 'Shape_Length', 'SLOPE', 'VOLUME_MERGED', 'MVMT_AZIMUTH_DEG',
    'DESCRIPTION', 'REF_ID_COD', 'FAIL_DEPTH', 'HS_HEIGHT', 'AREA',
    'CONFIDENCE', 'RELATIVE_AGE', 'MOVE_CODE', 'AVG_SCARP_DIST_FT',
    'FAN_HEIGHT', 'TYPE_MOVE', 'GEOL', 'MAP_UNIT_L', 'DEEP_SHAL',
    'NAME', 'Longitude', 'Latitude', 'Type', 'Material',
    'Discharge estimate (m3/s)', 'DATE_MOVE', 'Point_location',
    'Timing', 'Reference', 'Trigger', 'Event_verification',
    'Contributo', 'Watercours', 'Study_area', 'Cont_details',
    'YEAR', 'Type_details', 'DATE_RANGE', 'Size_class',
    'Resource_road_type', 'Resource_road_activity', 'Bedrock_type',
    'Comment', 'Volume_estimate_method', 'MONTH', 'DAY', 'REACTIVATION'
]

print("Analyzing origin datasets for all columns...")
origins_by_value = find_origins_by_value(landslides, all_columns)

# %%
# Function to find unique origins for each valid value in specified columns
def find_origins_by_value(df, columns):
    results = {}
    
    for col in columns:
        print(f"\n=== {col} ===")
        
        # Check if column exists
        if col not in df.columns:
            print(f"Column {col} not found in dataframe")
            continue
            
        # Filter for valid (non-null, non-empty) values
        valid_mask = df[col].notna() & (df[col] != '')
        
        if valid_mask.sum() == 0:
            print(f"No valid values found in {col}")
            continue
            
        # Show unique origins for this column
        unique_origins = df[valid_mask]['original_dataset'].unique()
        print(f"Unique origins: {list(unique_origins)}")
        
        # Group by column value and show origin datasets
        value_origins = df[valid_mask].groupby(col)['original_dataset'].unique()
        
        print(f"Total unique values: {len(value_origins)}")
        
        # # Show first 10 values as examples
        # for i, (value, origins) in enumerate(value_origins.items()):
        #     if i < 10:  # Show first 10 examples
        #         print(f"  {value}: {list(origins)}")
        #     elif i == 10:
        #         print(f"  ... and {len(value_origins) - 10} more values")
        #         break
        
        results[col] = value_origins
    
    return results

# All columns from your completeness results
all_columns = [
    'geometry', 'original_dataset', 'MATERIAL', 'MOVEMENT', 'LANDSLIDE_ID',
    'Shape_Area', 'Shape_Length', 'SLOPE', 'VOLUME_MERGED', 'MVMT_AZIMUTH_DEG',
    'DESCRIPTION', 'REF_ID_COD', 'FAIL_DEPTH', 'HS_HEIGHT', 'AREA',
    'CONFIDENCE', 'RELATIVE_AGE', 'MOVE_CODE', 'AVG_SCARP_DIST_FT',
    'FAN_HEIGHT', 'TYPE_MOVE', 'GEOL', 'MAP_UNIT_L', 'DEEP_SHAL',
    'NAME', 'Longitude', 'Latitude', 'Type', 'Material',
    'Discharge estimate (m3/s)', 'DATE_MOVE', 'Point_location',
    'Timing', 'Reference', 'Trigger', 'Event_verification',
    'Contributo', 'Watercours', 'Study_area', 'Cont_details',
    'YEAR', 'Type_details', 'DATE_RANGE', 'Size_class',
    'Resource_road_type', 'Resource_road_activity', 'Bedrock_type',
    'Comment', 'Volume_estimate_method', 'MONTH', 'DAY', 'REACTIVATION'
]

print("Analyzing origin datasets for all columns...")
origins_by_value = find_origins_by_value(landslides, all_columns)
# Out:
# Analyzing origin datasets for all columns...
#
# === geometry ===
# /var/folders/4l/861pz_dj397_gz1sywdvrptw0000gq/T/ipykernel_89009/1643580203.py:14: UserWarning: GeoSeries.notna() previously returned False for both missing (None) and empty geometries. Now, it only returns False for missing values. Since the calling GeoSeries contains empty geometries, the result has changed compared to previous versions of GeoPandas.
# Given a GeoSeries 's', you can use '~s.is_empty & s.notna()' to get back the old behaviour.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', 'GeoSeries.notna', UserWarning)
#   valid_mask = df[col].notna() & (df[col] != '')
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 90348
#   MULTIPOLYGON (EMPTY): ['WA']
#   MULTIPOLYGON (((-124.53287953207415 42.874662140959664, -124.53295961832292 42.874623478054964, -124.5330180714885 42.874624941461555, -124.53305202973584 42.87462371361384, -124.53318245510326 42.874683378378805, -124.53324862183396 42.87472748203755, -124.53339041904049 42.874811771929124, -124.53344203148932 42.87485640267738, -124.53344147317704 42.87492080270478, -124.53336623839581 42.874959290524174, -124.53322841514391 42.875007194363334, -124.53309886135146 42.87503333847575, -124.53302368017852 42.875060497691585, -124.53292495598158 42.87513560087509, -124.53290242219597 42.875186489606335, -124.5328579382197 42.87520002008438, -124.53281912806993 42.8752014232834, -124.53276192143083 42.87517010893017, -124.53271796913185 42.87514308455673, -124.5326881207834 42.87508455219724, -124.53265800934186 42.87497357165508, -124.53261496177255 42.87486305880079, -124.53265621192394 42.87481328236861, -124.53270790717593 42.874786376821355, -124.53278823096758 42.87475128236664, -124.53283897219376 42.87471010452296, -124.53287953207415 42.874662140959664))): ['OR']
#   MULTIPOLYGON (((-124.53179975106166 42.87524125478232, -124.53193972306323 42.87522546543621, -124.53204716574422 42.87523231142763, -124.5321172301378 42.8752619690409, -124.53224328001322 42.87532894600835, -124.53232034221168 42.875390539981936, -124.53236050070723 42.87548208237004, -124.53237982336617 42.87555291745433, -124.53233687671553 42.87556519983382, -124.53221559513705 42.87556958418711, -124.53204603714724 42.87557929042596, -124.53190511186875 42.87558080761598, -124.53178844217861 42.87558144789251, -124.53172299081082 42.87554804732051, -124.53169102143318 42.875506282702716, -124.53167122274249 42.875428310926466, -124.53167496566775 42.875338759331, -124.53171385801035 42.87526581997566, -124.53179975106166 42.87524125478232))): ['OR']
#   MULTIPOLYGON (((-124.53151717612917 42.87229967093478, -124.53164145091866 42.8722188761796, -124.53175299658686 42.87223868835262, -124.53181194205304 42.87244162072538, -124.53178394146136 42.87260477588125, -124.53167101246493 42.87266131555667, -124.53152002175447 42.87263339062055, -124.531427354268 42.87250797971005, -124.53141516453103 42.8724225800686, -124.53151717612917 42.87229967093478))): ['OR']
#   MULTIPOLYGON (((-124.5319357763803 42.872742354424425, -124.53213215380723 42.87267325938755, -124.53223659739227 42.87268379035174, -124.53236680373676 42.87278876762397, -124.53257812405026 42.87294327072089, -124.53264598511728 42.87298850657859, -124.5325895260316 42.87310381468864, -124.53261166519317 42.87315323691925, -124.53256044665632 42.8732600049242, -124.53238018173884 42.87337620662158, -124.53227149503823 42.87339921177768, -124.53215157096258 42.87335108858608, -124.53210499154697 42.87324356106896, -124.53209883555975 42.873241963163125, -124.53202101041897 42.87314462952276, -124.53188369961603 42.873030371138576, -124.53188476403056 42.872949260698654, -124.53192431926473 42.87286199057346, -124.5319357763803 42.872742354424425))): ['OR']
#   MULTIPOLYGON (((-124.53282220544577 42.873296883015996, -124.53302240061838 42.87328487528278, -124.5331125275198 42.873372225959585, -124.53315345484236 42.87349950657158, -124.5332890693117 42.87368535849888, -124.53336774402756 42.873892346150285, -124.53329605892112 42.87408092577645, -124.53326424549176 42.87418699154841, -124.5331549217018 42.87420048304861, -124.53299682186001 42.87416327947805, -124.53288728801012 42.87407663034496, -124.53276153064343 42.87403825706177, -124.53252485886846 42.87398958690645, -124.53247555750845 42.873833995393795, -124.53240419838583 42.87373642819072, -124.53235001856294 42.8736048572474, -124.53247440480675 42.87342867974928, -124.53282220544577 42.873296883015996))): ['OR']
#   MULTIPOLYGON (((-124.53285035688806 42.87429837389554, -124.53290284770715 42.87421063567518, -124.53294992811666 42.8741874737606, -124.53301599361588 42.87418556354953, -124.53308378721549 42.874224521116446, -124.53310946782042 42.87422213078358, -124.53313928220378 42.874255737648106, -124.5331617873702 42.87430142007253, -124.53314476756654 42.87433780275511, -124.53309959383172 42.87438950926144, -124.53302626740151 42.874456541311744, -124.53296972227979 42.87448362237683, -124.532931151091 42.87448859389777, -124.53291079231869 42.87447502327734, -124.53288415113008 42.87444021926528, -124.53284462605119 42.87443091852198, -124.5328145655172 42.874417698661894, -124.53285035688806 42.87429837389554))): ['OR']
#   MULTIPOLYGON (((-124.53410413413219 42.87370271749455, -124.53424942927661 42.873693885497524, -124.53436529939792 42.87375407438373, -124.53444355467461 42.87383350826671, -124.53453127199398 42.87390902203785, -124.53450598282441 42.87396716372725, -124.53448967962933 42.87401425055144, -124.53440792514343 42.87402793748908, -124.53428736124926 42.87404302807601, -124.53415399440892 42.87401208537792, -124.5340504497238 42.8739907937742, -124.533999076124 42.873949731597, -124.53399478230733 42.873885506143964, -124.53400941605977 42.87381344322872, -124.53410413413219 42.87370271749455))): ['OR']
#   MULTIPOLYGON (((-124.5345533541913 42.87302683555795, -124.53464263500449 42.873004530096644, -124.53472767524954 42.873015760641934, -124.53478716078311 42.87303268476146, -124.5348763354307 42.87310576089635, -124.53496773851256 42.87321213994439, -124.53502298266896 42.87326259917309, -124.53505829713697 42.87333716311269, -124.53506014285547 42.8733433994173, -124.53506777816015 42.87336920607431, -124.53509575324823 42.87340575023432, -124.53508644828064 42.8734847734773, -124.5350470839801 42.87355057831969, -124.53497137469937 42.87358193065233, -124.53492771420032 42.87358351008733, -124.53481788696543 42.87354098592887, -124.53475219875419 42.87350401882662, -124.53465040459756 42.87343616736447, -124.53461946848269 42.873337139254645, -124.53461102313655 42.87325653666302, -124.53457159111255 42.8732026250122, -124.534486021172 42.873086498051634, -124.5345533541913 42.87302683555795))): ['OR']
#   MULTIPOLYGON (((-124.53425953802042 42.872305994933896, -124.53433664912751 42.87212094483038, -124.53449697175243 42.8719005447767, -124.53472218514827 42.871777944209505, -124.53489252609182 42.871707401350456, -124.53513623654561 42.87170499133395, -124.53516351973131 42.87177676720197, -124.53517507837817 42.87185265191652, -124.53526266103528 42.87190194101169, -124.53536127177887 42.87192221847461, -124.53544143301588 42.87195746920838, -124.53550409933457 42.87202196635586, -124.53557387059449 42.872095744831334, -124.53556761659225 42.872196118290425, -124.53561989187256 42.8722991432645, -124.5356414196017 42.8724271250124, -124.53566846012284 42.872540600555325, -124.53557589361704 42.872610714291596, -124.53547494940159 42.872652517574274, -124.53535979669695 42.87267575976696, -124.53513341434105 42.87268394995861, -124.53499790280422 42.87269362156519, -124.53480810077755 42.87266710506281, -124.53465297330033 42.87257733871342, -124.53450494969209 42.87249685272668, -124.53440124901732 42.872400456626536, -124.53425953802042 42.872305994933896))): ['OR']
#   ... and 90338 more values
#
# === original_dataset ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 3
#   BC: ['BC']
#   OR: ['OR']
#   WA: ['WA']
#
# === MATERIAL ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 12
#   <NA>: ['OR']
#   Complex: ['OR', 'BC']
#   Debris: ['OR', 'BC']
#   Debris+Earth: ['OR']
#   Debris+Rock: ['OR']
#   Earth: ['OR', 'BC']
#   Earth or debris: ['WA']
#   Earth+Rock: ['OR']
#   Other: ['OR']
#   Rock: ['OR', 'WA', 'BC']
#   ... and 2 more values
#
# === MOVEMENT ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 25
#   <NA>: ['OR']
#   Avalanche: ['WA', 'BC']
#   Complex: ['OR', 'WA', 'BC']
#   Complex+Flow: ['OR']
#   Complex+Slide+Flow: ['OR']
#   Complex+Slide-Rotational+Flow: ['OR']
#   Complex+Slide-Translational+Flow: ['OR']
#   Deformation: ['BC']
#   Fall: ['OR', 'BC']
#   Flood: ['BC']
#   ... and 15 more values
#
# === LANDSLIDE_ID ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 89733
#   1: ['WA']
#   10: ['WA']
#   100: ['WA']
#   10000: ['WA']
#   10001: ['WA']
#   10002: ['WA']
#   10003: ['WA']
#   10004: ['WA']
#   10005: ['WA']
#   10006: ['WA']
#   ... and 89723 more values
#
# === Shape_Area ===
# Unique origins: ['OR', 'WA']
# Total unique values: 86279
#   0.3598115765204488: ['OR']
#   2.3416473311633: ['OR']
#   7.881682320975745: ['OR']
#   8.540352513396058: ['OR']
#   9.006112552185066: ['OR']
#   16.68647547937363: ['OR']
#   18.62183262735297: ['OR']
#   31.355786959620332: ['OR']
#   36.15099571114082: ['OR']
#   70.60515959432604: ['OR']
#   ... and 86269 more values
#
# === Shape_Length ===
# Unique origins: ['OR', 'WA']
# Total unique values: 86279
#   3.1028931223919156: ['OR']
#   7.471484313315232: ['OR']
#   14.575427184483663: ['OR']
#   24.334119268195174: ['OR']
#   29.842368599453316: ['OR']
#   41.41695021827685: ['OR']
#   43.03331558107435: ['OR']
#   44.7050712003964: ['OR']
#   45.55948348980968: ['OR']
#   47.54603184517916: ['OR']
#   ... and 86269 more values
#
# === SLOPE ===
# Unique origins: ['OR', 'WA']
# Total unique values: 6658
#   0.0: ['OR']
#   0.91050398: ['OR']
#   0.92900848: ['OR']
#   1.0: ['OR']
#   1.1499712: ['OR']
#   1.3944031: ['OR']
#   1.4065437: ['OR']
#   1.4578748: ['OR']
#   1.45883: ['OR']
#   1.4687846: ['OR']
#   ... and 6648 more values
#
# === VOLUME_MERGED ===
# Unique origins: ['OR', 'WA']
# Total unique values: 55298
#   0.0: ['OR']
#   44.1936: ['OR']
#   48.854301: ['OR']
#   73.588997: ['OR']
#   83.283501: ['OR']
#   181.47177: ['OR']
#   217.61838: ['OR']
#   220.59526: ['OR']
#   223.92155: ['OR']
#   242.63329: ['OR']
#   ... and 55288 more values
#
# === MVMT_AZIMUTH_DEG ===
# Unique origins: ['OR', 'WA']
# Total unique values: 45
#   0.0: ['OR', 'WA']
#   20.0: ['OR']
#   22.5: ['OR', 'WA']
#   24.700001: ['OR']
#   25.0: ['OR']
#   35.0: ['OR']
#   37.5: ['OR']
#   45.0: ['OR', 'WA']
#   67.5: ['OR', 'WA']
#   90.0: ['OR', 'WA']
#   ... and 35 more values
#
# === DESCRIPTION ===
# Unique origins: ['OR']
# Total unique values: 3
#   Fan: ['OR']
#   Landslide: ['OR']
#   Talus-Colluvium: ['OR']
#
# === REF_ID_COD ===
# Unique origins: ['OR']
# Total unique values: 346
#   AchJA1991: ['OR']
#   AllaJC2001: ['OR']
#   AlleJE1988: ['OR']
#   AndeJL1978: ['OR']
#   AshlRP1966: ['OR']
#   BacoCRUnpub: ['OR']
#   BaldEM1952: ['OR']
#   BaldEM1955: ['OR']
#   BaldEM1956: ['OR']
#   BaldEM1961: ['OR']
#   ... and 336 more values
#
# === FAIL_DEPTH ===
# Unique origins: ['OR', 'WA']
# Total unique values: 13694
#   0.0: ['OR']
#   0.353701: ['OR']
#   0.38314199: ['OR']
#   0.50017101: ['OR']
#   0.80264908: ['OR']
#   0.92718399: ['OR']
#   0.96592587: ['OR']
#   0.97366816: ['OR']
#   0.97828037: ['OR']
#   1.0: ['OR', 'WA']
#   ... and 13684 more values
#
# === HS_HEIGHT ===
# Unique origins: ['OR', 'WA']
# Total unique values: 1516
#   0.0: ['OR']
#   0.5: ['OR']
#   0.92999297: ['OR']
#   1.0: ['OR', 'WA']
#   1.19995: ['OR']
#   1.4800415: ['OR']
#   1.65997: ['OR']
#   2.0: ['OR', 'WA']
#   3.0: ['OR', 'WA']
#   3.1300001: ['OR']
#   ... and 1506 more values
#
# === AREA ===
# Unique origins: ['OR', 'BC']
# Total unique values: 42494
#   0: ['BC']
#   0.0: ['OR']
#   1000: ['BC']
#   1000.88: ['OR']
#   1000.92: ['OR']
#   10000: ['BC']
#   10000.7: ['OR']
#   10002.978: ['OR']
#   100034.1: ['OR']
#   10003733.0: ['OR']
#   ... and 42484 more values
#
# === CONFIDENCE ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 6
#   High: ['OR', 'BC']
#   High (30-40): ['WA']
#   Low: ['OR', 'BC']
#   Low (1-10): ['WA']
#   Moderate: ['OR', 'BC']
#   Moderate (11-29): ['WA']
#
# === RELATIVE_AGE ===
# Unique origins: ['OR', 'WA']
# Total unique values: 5
#   Historic (</=150 years): ['WA']
#   Historic (<150 years): ['OR']
#   Historic (<150yrs): ['OR']
#   Pre-Historic (>150yrs): ['OR']
#   Pre-historic (>150 years): ['WA']
#
# === MOVE_CODE ===
# Unique origins: ['OR', 'WA']
# Total unique values: 222
#   C: ['OR']
#   C+RS-R+DFL: ['OR']
#   C+RS-R+EFL: ['OR']
#   C+RS-R+ES-T: ['OR']
#   C+RS-T+EFL: ['OR']
#   C-EFL: ['OR']
#   C-ES+EFL: ['OR']
#   DA: ['WA']
#   DA+ES-R: ['WA']
#   DA+ES-T: ['WA']
#   ... and 212 more values
#
# === AVG_SCARP_DIST_FT ===
# Unique origins: ['OR', 'WA']
# Total unique values: 2719
#   0.0: ['OR']
#   4.0: ['WA']
#   5.0: ['WA']
#   6.0: ['WA']
#   7.0: ['WA']
#   8.0: ['WA']
#   9.0: ['WA']
#   10.0: ['OR', 'WA']
#   10.5: ['OR']
#   11.0: ['WA']
#   ... and 2709 more values
#
# === FAN_HEIGHT ===
# Unique origins: ['OR']
# Total unique values: 1437
#   0.0: ['OR']
#   0.5: ['OR']
#   0.59997559: ['OR']
#   0.94006348: ['OR']
#   1.0: ['OR']
#   1.0500488: ['OR']
#   1.1499023: ['OR']
#   1.3000031: ['OR']
#   1.6300049: ['OR']
#   1.6400146: ['OR']
#   ... and 1427 more values
#
# === TYPE_MOVE ===
# Unique origins: ['OR']
# Total unique values: 12
#   Complex: ['OR']
#   Earth: ['OR']
#   Fall: ['OR']
#   Flow: ['OR']
#   Flow+Flow: ['OR']
#   Flow+Slide: ['OR']
#   Slide: ['OR']
#   Slide : ['OR']
#   Slide+Flow: ['OR']
#   Slide+Slide: ['OR']
#   ... and 2 more values
#
# === GEOL ===
# Unique origins: ['OR']
# Total unique values: 1395
#    QTb, Tf, Tpr: ['OR']
#    QTb, Tt, Qal1: ['OR']
#    QTtu, Qal: ['OR']
#    QTtu, Tf, Qal: ['OR']
#    QTvu, Tfsh, Tfg: ['OR']
#    Qal: ['OR']
#    Qe: ['OR']
#    Qe, Tt: ['OR']
#    Tfsh: ['OR']
#    Tgo: ['OR']
#   ... and 1385 more values
#
# === MAP_UNIT_L ===
# Unique origins: ['OR']
# Total unique values: 189
#   10: ['OR']
#   <Null>: ['OR']
#   Aaf: ['OR']
#   Ab: ['OR']
#   Acid Igneous - Colluvium: ['OR']
#   Active Landslide: ['OR']
#   Active slump/Debris slide/Landslide: ['OR']
#   Active slumps (potential failures): ['OR']
#   Active slumps / Debris slides: ['OR']
#   Active slumps / Landslide landforms: ['OR']
#   ... and 179 more values
#
# === DEEP_SHAL ===
# Unique origins: ['OR']
# Total unique values: 5
#    : ['OR']
#   <Null>: ['OR']
#   Deep: ['OR']
#   Shallow: ['OR']
#   Shallow : ['OR']
#
# === NAME ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 1120
#    : ['OR']
#    Ansell   Place: ['BC']
#    Elephant Hill Fire: ['BC']
#   'Quarter Mile' Highway 23N: ['BC']
#   0.5 km N Horseshoe bay: ['BC']
#   1 km S Murrin L: ['BC']
#   1 km south of Funct on Junct on: ['BC']
#   1.3 km N Whistler: ['BC']
#   1.5 km N of Horseshoe Bay: ['BC']
#   10 Mile Slide: ['BC']
#   ... and 1110 more values
#
# === Longitude ===
# Unique origins: ['BC']
# Total unique values: 3823
#   -128.3368: ['BC']
#   -128.3157: ['BC']
#   -128.1971: ['BC']
#   -128.1911: ['BC']
#   -128.187: ['BC']
#   -128.1838: ['BC']
#   -128.1819: ['BC']
#   -128.1773: ['BC']
#   -128.1769: ['BC']
#   -128.1732: ['BC']
#   ... and 3813 more values
#
# === Latitude ===
# Unique origins: ['BC']
# Total unique values: 4114
#   48.33996: ['BC']
#   48.394001: ['BC']
#   48.407505: ['BC']
#   48.42146: ['BC']
#   48.452666: ['BC']
#   48.462145: ['BC']
#   48.46483: ['BC']
#   48.475433: ['BC']
#   48.50675136: ['BC']
#   48.507362: ['BC']
#   ... and 4104 more values
#
# === Type ===
# Unique origins: ['BC']
# Total unique values: 21
#   Debris avalanche: ['BC']
#   Debris fall: ['BC']
#   Debris flood: ['BC']
#   Debris flow: ['BC']
#   Debris flow : ['BC']
#   Debris slide: ['BC']
#   Earth fall: ['BC']
#   Earth flow: ['BC']
#   Earth slide: ['BC']
#   Flood: ['BC']
#   ... and 11 more values
#
# === Material ===
# Unique origins: ['BC']
# Total unique values: 5
#    Surficial: ['BC']
#   Anthropogenic: ['BC']
#   Rock: ['BC']
#   Surficial: ['BC']
#   Surficial : ['BC']
#
# === Discharge estimate (m3/s) ===
# Unique origins: ['BC']
# Total unique values: 25
#   -1: ['BC']
#   0: ['BC']
#   1: ['BC']
#   111: ['BC']
#   115: ['BC']
#   12: ['BC']
#   125: ['BC']
#   14: ['BC']
#   16: ['BC']
#   199: ['BC']
#   ... and 15 more values
#
# === DATE_MOVE ===
# Unique origins: ['OR']
# Total unique values: 1
#    : ['OR']
#
# === Point_location ===
# Unique origins: ['BC']
# Total unique values: 5
#    Infrastructure: ['BC']
#   Deposit: ['BC']
#   Headscarp: ['BC']
#   Infrastructure: ['BC']
#   Source: ['BC']
#
# === Timing ===
# Unique origins: ['BC']
# Total unique values: 324
#    2018-Aug-03: ['BC']
#    ug  1958: ['BC']
#   1/10/1985: ['BC']
#   1/11/1981: ['BC']
#   1/5/2003: ['BC']
#   1/9/1976: ['BC']
#   1/9/1980: ['BC']
#   10/1/1983: ['BC']
#   10/6/1995: ['BC']
#   10/9/2005: ['BC']
#   ... and 314 more values
#
# === Reference ===
# Unique origins: ['BC']
# Total unique values: 59
#   BC Flood Debris Dashboard: ['BC']
#   BGC: ['BC']
#   BGC (2016a): ['BC']
#   BGC; 2023: ['BC']
#   Blais-Stevens and Septer; 2008: ['BC']
#   Blais-Stevens et al. 2011: ['BC']
#   Blais-Stevens; 2020: ['BC']
#   Boultbee et al. 2002: ['BC']
#   Bovis and Evans; 1995: ['BC']
#   Bovis and Jones; 1992: ['BC']
#   ... and 49 more values
#
# === Trigger ===
# Unique origins: ['BC']
# Total unique values: 15
#   Anthropogenic: ['BC']
#   Bank erosion: ['BC']
#   Dam failure: ['BC']
#   Deglaciation: ['BC']
#   Earthquake: ['BC']
#   Earthquake?: ['BC']
#   Freeze-thaw: ['BC']
#   Heat wave: ['BC']
#   Moraine dammed lake: ['BC']
#   Precipitation: ['BC']
#   ... and 5 more values
#
# === Event_verification ===
# Unique origins: ['BC']
# Total unique values: 8
#    Satellite: ['BC']
#   Event: ['BC']
#   Event & Field: ['BC']
#   Field: ['BC']
#   Lidar: ['BC']
#   Record/Report: ['BC']
#   Report: ['BC']
#   Satellite: ['BC']
#
# === Contributo ===
# Unique origins: ['BC']
# Total unique values: 11
#    Post-Wildfire: ['BC']
#   Large Landslide: ['BC']
#   Lateral Instability: ['BC']
#   Logging: ['BC']
#   Post-Wildfire: ['BC']
#   Post-wildfire: ['BC']
#   Post-wildfire & Resource Road: ['BC']
#   Resource Road: ['BC']
#   Resource road: ['BC']
#   River erosion: ['BC']
#   ... and 1 more values
#
# === Watercours ===
# Unique origins: ['BC']
# Total unique values: 113
#   Allenby Road: ['BC']
#   Anderson Creek: ['BC']
#   Baldwin Creek: ['BC']
#   Belgrove Creek: ['BC']
#   Bings Creek: ['BC']
#   Bottletop Creek: ['BC']
#   Boulder Creek: ['BC']
#   Brook Creek: ['BC']
#   Burnett Falls: ['BC']
#   Camilos Creek: ['BC']
#   ... and 103 more values
#
# === Study_area ===
# Unique origins: ['BC']
# Total unique values: 10
#   Capital Regional District: ['BC']
#   Cowichan Valley Regional District: ['BC']
#   Fraser Valley Regional District: ['BC']
#   K60639: ['BC']
#   K62088: ['BC']
#   K62317: ['BC']
#   Metro Vancouver Regional District: ['BC']
#   Squamish Lillooet Regional District: ['BC']
#   Sunshine Coast Regional District: ['BC']
#   Thompson-Nicola Regional District: ['BC']
#
# === Cont_details ===
# Unique origins: ['BC']
# Total unique values: 57
#   1960: ['BC']
#   1961: ['BC']
#   1962: ['BC']
#   1963: ['BC']
#   1964: ['BC']
#   1968: ['BC']
#   1969: ['BC']
#   1971: ['BC']
#   1973: ['BC']
#   1974: ['BC']
#   ... and 47 more values
#
# === YEAR ===
# Unique origins: ['OR', 'WA']
# Total unique values: 88
#   1890.0: ['OR']
#   1907: ['WA']
#   1910: ['WA']
#   1914: ['WA']
#   1923: ['WA']
#   1929: ['WA']
#   1932.0: ['OR']
#   1934: ['WA']
#   1950: ['WA']
#   1950.0: ['OR']
#   ... and 78 more values
#
# === Type_details ===
# Unique origins: ['BC']
# Total unique values: 17
#   1. ROCK fall (rock/ice): ['BC']
#   11. SOIL rotational slide (clay/silt): ['BC']
#   12. SOIL planar slide (clay/silt): ['BC']
#   13. SOIL slide (gravel/sand/debris): ['BC']
#   20. SOIL flowslide (sand/silt/debris): ['BC']
#   25. SOIL debris avalanche: ['BC']
#   7. ROCK planar slide: ['BC']
#   9. ROCK compound slide: ['BC']
#   Debris flood/flood: ['BC']
#   Debris flow/Debris flood: ['BC']
#   ... and 7 more values
#
# === DATE_RANGE ===
# Unique origins: ['OR']
# Total unique values: 24
#   1960-1961: ['OR']
#   1976-1978: ['OR']
#   1978-1981: ['OR']
#   1995-2000: ['OR']
#   1995-2003: ['OR']
#   1995-2005: ['OR']
#   1996: ['OR']
#   1996-1997: ['OR']
#   1999-2000: ['OR']
#   2000-2005: ['OR']
#   ... and 14 more values
#
# === Size_class ===
# Unique origins: ['BC']
# Total unique values: 133
#   1: ['BC']
#   100: ['BC']
#   1000: ['BC']
#   1000-1500: ['BC']
#   1000-2000: ['BC']
#   10000-30000: ['BC']
#   100;000 : ['BC']
#   100 : ['BC']
#   1020: ['BC']
#   10 : ['BC']
#   ... and 123 more values
#
# === Resource_road_type ===
# Unique origins: ['BC']
# Total unique values: 5
#   Forest Service Road: ['BC']
#   Forest service road: ['BC']
#   Road Permit: ['BC']
#   Road permit: ['BC']
#   Unknown: ['BC']
#
# === Resource_road_activity ===
# Unique origins: ['BC']
# Total unique values: 3
#   Active: ['BC']
#   Retired: ['BC']
#   Unknown: ['BC']
#
# === Bedrock_type ===
# Unique origins: ['BC']
# Total unique values: 15
#   1,000: ['BC']
#   10: ['BC']
#   100: ['BC']
#   20: ['BC']
#   30: ['BC']
#   5: ['BC']
#   500: ['BC']
#   700: ['BC']
#   >2,000: ['BC']
#   Granitic: ['BC']
#   ... and 5 more values
#
# === Comment ===
# Unique origins: ['BC']
# Total unique values: 15
#   A landslide in a small creek triggered a Debris flow which damaged a water intake. (Spring 2005.): ['BC']
#   After the 1998 Silver Creek wildfire near Salmon Arm; a Debris flood in May 1999 affected private property: ['BC']
#   At the 1994 Tiffen Creek fire near Lillooet; heavy rains extinguished the fire and also caused severe erosion.: ['BC']
#   Between late June and early July (imagery): ['BC']
#   Debris floods and flash flooding posed risk to infrastructure; 50 homes; and 150 people: ['BC']
#   Events July 31; 2018 and Aug 2; 2018: ['BC']
#   Imagery: ['BC']
#   Landslide: ['BC']
#   Landslide dammed lake: ['BC']
#   Location based on 2004 Google Earth imagery: ['BC']
#   ... and 5 more values
#
# === Volume_estimate_method ===
# Unique origins: ['BC']
# Total unique values: 7
#   450: ['BC']
#   7000: ['BC']
#   Estimated: ['BC']
#   Field Measurement: ['BC']
#   Field measurement: ['BC']
#   Lidar Change Detection (LCD): ['BC']
#   rr: ['BC']
#
# === MONTH ===
# Unique origins: ['OR']
# Total unique values: 9
#   01: ['OR']
#   02: ['OR']
#   03: ['OR']
#   04: ['OR']
#   06: ['OR']
#   07: ['OR']
#   10: ['OR']
#   11: ['OR']
#   12: ['OR']
#
# === DAY ===
# Unique origins: ['OR']
# Total unique values: 12
#   01: ['OR']
#   02: ['OR']
#   03: ['OR']
#   06: ['OR']
#   08: ['OR']
#   09: ['OR']
#   12: ['OR']
#   17: ['OR']
#   23: ['OR']
#   24: ['OR']
#   ... and 2 more values
#
# === REACTIVATION ===
# Unique origins: ['OR']
# Total unique values: 15
#   1965, 1980, 1985, 1995, 1996: ['OR']
#   1970, 2006, Sept 21: ['OR']
#   1989 mitigated: ['OR']
#   1995: ['OR']
#   1997: ['OR']
#   2000-2005: ['OR']
#   2005: ['OR']
#   2005-2009: ['OR']
#   2005-2009, 2009-2011: ['OR']
#   2006: ['OR']
#   ... and 5 more values

# %%
# Function to find unique origins for each valid value in specified columns
def find_origins_by_value(df, columns):
    results = {}
    
    for col in columns:
        print(f"\n=== {col} ===")
        
        # Check if column exists
        if col not in df.columns:
            print(f"Column {col} not found in dataframe")
            continue
            
        # Filter for valid (non-null, non-empty) values
        valid_mask = df[col].notna() & (df[col] != '')
        
        if valid_mask.sum() == 0:
            print(f"No valid values found in {col}")
            continue
            
        # Show unique origins for this column
        unique_origins = df[valid_mask]['original_dataset'].unique()
        print(f"Unique origins: {list(unique_origins)}")
        
        # Group by column value and show origin datasets
        value_origins = df[valid_mask].groupby(col)['original_dataset'].unique()
        
        print(f"Total unique values: {len(value_origins)}")
        
        # # Show first 10 values as examples
        # for i, (value, origins) in enumerate(value_origins.items()):
        #     if i < 10:  # Show first 10 examples
        #         print(f"  {value}: {list(origins)}")
        #     elif i == 10:
        #         print(f"  ... and {len(value_origins) - 10} more values")
        #         break
        
        results[col] = value_origins
    
    return results

# All columns from your completeness results
all_columns = [
    'geometry', 'original_dataset', 'MATERIAL', 'MOVEMENT', 'LANDSLIDE_ID',
    'Shape_Area', 'Shape_Length', 'SLOPE', 'VOLUME_MERGED', 'MVMT_AZIMUTH_DEG',
    'DESCRIPTION', 'REF_ID_COD', 'FAIL_DEPTH', 'HS_HEIGHT', 'AREA',
    'CONFIDENCE', 'RELATIVE_AGE', 'MOVE_CODE', 'AVG_SCARP_DIST_FT',
    'FAN_HEIGHT', 'TYPE_MOVE', 'GEOL', 'MAP_UNIT_L', 'DEEP_SHAL',
    'NAME', 'Longitude', 'Latitude', 'Type', 'Material',
    'Discharge estimate (m3/s)', 'DATE_MOVE', 'Point_location',
    'Timing', 'Reference', 'Trigger', 'Event_verification',
    'Contributo', 'Watercours', 'Study_area', 'Cont_details',
    'YEAR', 'Type_details', 'DATE_RANGE', 'Size_class',
    'Resource_road_type', 'Resource_road_activity', 'Bedrock_type',
    'Comment', 'Volume_estimate_method', 'MONTH', 'DAY', 'REACTIVATION'
]

print("Analyzing origin datasets for all columns...")
origins_by_value = find_origins_by_value(landslides, all_columns)
# Out:
# Analyzing origin datasets for all columns...
#
# === geometry ===
# Unique origins: ['OR', 'WA', 'BC']
# /var/folders/4l/861pz_dj397_gz1sywdvrptw0000gq/T/ipykernel_89009/724327343.py:14: UserWarning: GeoSeries.notna() previously returned False for both missing (None) and empty geometries. Now, it only returns False for missing values. Since the calling GeoSeries contains empty geometries, the result has changed compared to previous versions of GeoPandas.
# Given a GeoSeries 's', you can use '~s.is_empty & s.notna()' to get back the old behaviour.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', 'GeoSeries.notna', UserWarning)
#   valid_mask = df[col].notna() & (df[col] != '')
# Total unique values: 90348
#
# === original_dataset ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 3
#
# === MATERIAL ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 12
#
# === MOVEMENT ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 25
#
# === LANDSLIDE_ID ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 89733
#
# === Shape_Area ===
# Unique origins: ['OR', 'WA']
# Total unique values: 86279
#
# === Shape_Length ===
# Unique origins: ['OR', 'WA']
# Total unique values: 86279
#
# === SLOPE ===
# Unique origins: ['OR', 'WA']
# Total unique values: 6658
#
# === VOLUME_MERGED ===
# Unique origins: ['OR', 'WA']
# Total unique values: 55298
#
# === MVMT_AZIMUTH_DEG ===
# Unique origins: ['OR', 'WA']
# Total unique values: 45
#
# === DESCRIPTION ===
# Unique origins: ['OR']
# Total unique values: 3
#
# === REF_ID_COD ===
# Unique origins: ['OR']
# Total unique values: 346
#
# === FAIL_DEPTH ===
# Unique origins: ['OR', 'WA']
# Total unique values: 13694
#
# === HS_HEIGHT ===
# Unique origins: ['OR', 'WA']
# Total unique values: 1516
#
# === AREA ===
# Unique origins: ['OR', 'BC']
# Total unique values: 42494
#
# === CONFIDENCE ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 6
#
# === RELATIVE_AGE ===
# Unique origins: ['OR', 'WA']
# Total unique values: 5
#
# === MOVE_CODE ===
# Unique origins: ['OR', 'WA']
# Total unique values: 222
#
# === AVG_SCARP_DIST_FT ===
# Unique origins: ['OR', 'WA']
# Total unique values: 2719
#
# === FAN_HEIGHT ===
# Unique origins: ['OR']
# Total unique values: 1437
#
# === TYPE_MOVE ===
# Unique origins: ['OR']
# Total unique values: 12
#
# === GEOL ===
# Unique origins: ['OR']
# Total unique values: 1395
#
# === MAP_UNIT_L ===
# Unique origins: ['OR']
# Total unique values: 189
#
# === DEEP_SHAL ===
# Unique origins: ['OR']
# Total unique values: 5
#
# === NAME ===
# Unique origins: ['OR', 'WA', 'BC']
# Total unique values: 1120
#
# === Longitude ===
# Unique origins: ['BC']
# Total unique values: 3823
#
# === Latitude ===
# Unique origins: ['BC']
# Total unique values: 4114
#
# === Type ===
# Unique origins: ['BC']
# Total unique values: 21
#
# === Material ===
# Unique origins: ['BC']
# Total unique values: 5
#
# === Discharge estimate (m3/s) ===
# Unique origins: ['BC']
# Total unique values: 25
#
# === DATE_MOVE ===
# Unique origins: ['OR']
# Total unique values: 1
#
# === Point_location ===
# Unique origins: ['BC']
# Total unique values: 5
#
# === Timing ===
# Unique origins: ['BC']
# Total unique values: 324
#
# === Reference ===
# Unique origins: ['BC']
# Total unique values: 59
#
# === Trigger ===
# Unique origins: ['BC']
# Total unique values: 15
#
# === Event_verification ===
# Unique origins: ['BC']
# Total unique values: 8
#
# === Contributo ===
# Unique origins: ['BC']
# Total unique values: 11
#
# === Watercours ===
# Unique origins: ['BC']
# Total unique values: 113
#
# === Study_area ===
# Unique origins: ['BC']
# Total unique values: 10
#
# === Cont_details ===
# Unique origins: ['BC']
# Total unique values: 57
#
# === YEAR ===
# Unique origins: ['OR', 'WA']
# Total unique values: 88
#
# === Type_details ===
# Unique origins: ['BC']
# Total unique values: 17
#
# === DATE_RANGE ===
# Unique origins: ['OR']
# Total unique values: 24
#
# === Size_class ===
# Unique origins: ['BC']
# Total unique values: 133
#
# === Resource_road_type ===
# Unique origins: ['BC']
# Total unique values: 5
#
# === Resource_road_activity ===
# Unique origins: ['BC']
# Total unique values: 3
#
# === Bedrock_type ===
# Unique origins: ['BC']
# Total unique values: 15
#
# === Comment ===
# Unique origins: ['BC']
# Total unique values: 15
#
# === Volume_estimate_method ===
# Unique origins: ['BC']
# Total unique values: 7
#
# === MONTH ===
# Unique origins: ['OR']
# Total unique values: 9
#
# === DAY ===
# Unique origins: ['OR']
# Total unique values: 12
#
# === REACTIVATION ===
# Unique origins: ['OR']
# Total unique values: 15
